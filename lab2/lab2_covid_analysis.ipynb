# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
# preprocessing data
dxy_area = pd.read_csv('DXYArea.csv')
dxy_area = dxy_area[ (dxy_area.countryName == '中国') & (dxy_area.provinceName != '中国')]
dxy_area['updateTime'] = pd.to_datetime(dxy_area.updateTime).dt.date
dxy_area = dxy_area.drop_duplicates(['provinceName','updateTime']).reset_index(drop=True)
dxy_area = dxy_area[['provinceName','province_confirmedCount','province_curedCount','province_deadCount','updateTime']]

# %%
current = dxy_area.drop_duplicates(['provinceName']).reset_index(drop=True)
current['provinceName'][0] = '香港'
current['provinceName'][1] = '新疆'
current['provinceName'][2] = '北京'
current['provinceName'][3] = '四川'
current['provinceName'][4] = '甘肃'
current['provinceName'][5] = '上海'
current['provinceName'][6] = '广东'
current['provinceName'][7] = '台湾'
current['provinceName'][8] = '河北'
current['provinceName'][9] = '陕西'
current['provinceName'][10] = '山西'
current['provinceName'][11] = '云南'
current['provinceName'][12] = '重庆'
current['provinceName'][13] = '内蒙古'
current['provinceName'][14] = '山东'
current['provinceName'][15] = '浙江'
current['provinceName'][16] = '天津'
current['provinceName'][17] = '辽宁'
current['provinceName'][18] = '福建'
current['provinceName'][19] = '江苏'
current['provinceName'][20] = '海南'
current['provinceName'][21] = '澳门'
current['provinceName'][22] = '吉林'
current['provinceName'][23] = '湖北'
current['provinceName'][24] = '江西'
current['provinceName'][25] = '黑龙江'
current['provinceName'][26] = '安徽'
current['provinceName'][27] = '贵州'
current['provinceName'][28] = '湖南'
current['provinceName'][29] = '河南'
current['provinceName'][30] = '广西'
current['provinceName'][31] = '宁夏'
current['provinceName'][32] = '青海'
current['provinceName'][33] = '西藏'
current
# Out:
#    provinceName  province_confirmedCount  province_curedCount  \
# 0            香港                     1655                 1254
# 1            新疆                       77                   73
# 2            北京                      929                  752
# 3            四川                      599                  590
# 4            甘肃                      167                  165
# 5            上海                      732                  691
# 6            广东                     1650                 1636
# 7            台湾                      451                  440
# 8            河北                      349                  340
# 9            陕西                      321                  315
# 10           山西                      201                  198
# 11           云南                      188                  183
# 12           重庆                      583                  576
# 13          内蒙古                      249                  237
# 14           山东                      793                  785
# 15           浙江                     1270                 1267
# 16           天津                      203                  195
# 17           辽宁                      164                  150
# 18           福建                      363                  361
# 19           江苏                      654                  654
# 20           海南                      171                  165
# 21           澳门                       46                   45
# 22           吉林                      155                  153
# 23           湖北                    68135                63623
# 24           江西                      932                  931
# 25          黑龙江                      947                  934
# 26           安徽                      991                  985
# 27           贵州                      147                  145
# 28           湖南                     1019                 1015
# 29           河南                     1276                 1254
# 30           广西                      254                  252
# 31           宁夏                       75                   75
# 32           青海                       18                   18
# 33           西藏                        1                    1
#
#     province_deadCount  updateTime
# 0                   10  2020-07-16
# 1                    3  2020-07-16
# 2                    9  2020-07-16
# 3                    3  2020-07-16
# 4                    2  2020-07-16
# 5                    7  2020-07-16
# 6                    8  2020-07-15
# 7                    7  2020-07-15
# 8                    6  2020-07-15
# 9                    3  2020-07-15
# 10                   0  2020-07-15
# 11                   2  2020-07-15
# 12                   6  2020-07-15
# 13                   1  2020-07-13
# 14                   7  2020-07-13
# 15                   1  2020-07-12
# 16                   3  2020-07-12
# 17                   2  2020-07-11
# 18                   1  2020-07-11
# 19                   0  2020-06-30
# 20                   6  2020-06-26
# 21                   0  2020-06-26
# 22                   2  2020-06-07
# 23                4512  2020-06-05
# 24                   1  2020-06-03
# 25                  13  2020-06-03
# 26                   6  2020-04-24
# 27                   2  2020-04-19
# 28                   4  2020-04-18
# 29                  22  2020-04-14
# 30                   2  2020-04-02
# 31                   0  2020-03-16
# 32                   0  2020-02-23
# 33                   0  2020-02-23

# %%
from pyecharts import Map

province = current['provinceName'].values.tolist()
confirmedCount = current['province_confirmedCount'].values.tolist()
# print(len(province), len(confirmedCount))

map = Map("Cumulative Confirmed Cases in China", '', width=1200, height=600)

range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
map.add("Confirmed Cases", province, confirmedCount, visual_range=[0, 2000], maptype='china', is_visualmap=True, visual_range_color=range_color, visual_text_color='#000', is_map_symbol_show=False, is_label_show=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="8de45c8f695f4014bcf40c30e77d7e35" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_8de45c8f695f4014bcf40c30e77d7e35 = echarts.init(document.getElementById('8de45c8f695f4014bcf40c30e77d7e35'), 'light', {renderer: 'canvas'});
#
# var option_8de45c8f695f4014bcf40c30e77d7e35 = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Cumulative Confirmed Cases in China",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "visualMap": {
#         "orient": "vertical",
#         "inRange": {
#             "color": [
#                 "#313695",
#                 "#4575b4",
#                 "#74add1",
#                 "#abd9e9",
#                 "#e0f3f8",
#                 "#ffffbf",
#                 "#fee090",
#                 "#fdae61",
#                 "#f46d43",
#                 "#d73027",
#                 "#a50026"
#             ]
#         },
#         "type": "continuous",
#         "max": 2000,
#         "min": 0,
#         "text": [
#             "high",
#             "low"
#         ],
#         "calculable": true,
#         "top": "bottom",
#         "showLabel": true,
#         "textStyle": {
#             "color": "#000"
#         },
#         "splitNumber": 5,
#         "left": "left"
#     },
#     "legend": [
#         {
#             "orient": "horizontal",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "Confirmed Cases"
#             ],
#             "left": "center",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "showLegendSymbol": false,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "type": "map",
#             "mapType": "china",
#             "name": "Confirmed Cases",
#             "symbol": "circle",
#             "roam": true,
#             "data": [
#                 {
#                     "value": 1655,
#                     "name": "\u9999\u6e2f"
#                 },
#                 {
#                     "value": 77,
#                     "name": "\u65b0\u7586"
#                 },
#                 {
#                     "value": 929,
#                     "name": "\u5317\u4eac"
#                 },
#                 {
#                     "value": 599,
#                     "name": "\u56db\u5ddd"
#                 },
#                 {
#                     "value": 167,
#                     "name": "\u7518\u8083"
#                 },
#                 {
#                     "value": 732,
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "value": 1650,
#                     "name": "\u5e7f\u4e1c"
#                 },
#                 {
#                     "value": 451,
#                     "name": "\u53f0\u6e7e"
#                 },
#                 {
#                     "value": 349,
#                     "name": "\u6cb3\u5317"
#                 },
#                 {
#                     "value": 321,
#                     "name": "\u9655\u897f"
#                 },
#                 {
#                     "value": 201,
#                     "name": "\u5c71\u897f"
#                 },
#                 {
#                     "value": 188,
#                     "name": "\u4e91\u5357"
#                 },
#                 {
#                     "value": 583,
#                     "name": "\u91cd\u5e86"
#                 },
#                 {
#                     "value": 249,
#                     "name": "\u5185\u8499\u53e4"
#                 },
#                 {
#                     "value": 793,
#                     "name": "\u5c71\u4e1c"
#                 },
#                 {
#                     "value": 1270,
#                     "name": "\u6d59\u6c5f"
#                 },
#                 {
#                     "value": 203,
#                     "name": "\u5929\u6d25"
#                 },
#                 {
#                     "value": 164,
#                     "name": "\u8fbd\u5b81"
#                 },
#                 {
#                     "value": 363,
#                     "name": "\u798f\u5efa"
#                 },
#                 {
#                     "value": 654,
#                     "name": "\u6c5f\u82cf"
#                 },
#                 {
#                     "value": 171,
#                     "name": "\u6d77\u5357"
#                 },
#                 {
#                     "value": 46,
#                     "name": "\u6fb3\u95e8"
#                 },
#                 {
#                     "value": 155,
#                     "name": "\u5409\u6797"
#                 },
#                 {
#                     "value": 68135,
#                     "name": "\u6e56\u5317"
#                 },
#                 {
#                     "value": 932,
#                     "name": "\u6c5f\u897f"
#                 },
#                 {
#                     "value": 947,
#                     "name": "\u9ed1\u9f99\u6c5f"
#                 },
#                 {
#                     "value": 991,
#                     "name": "\u5b89\u5fbd"
#                 },
#                 {
#                     "value": 147,
#                     "name": "\u8d35\u5dde"
#                 },
#                 {
#                     "value": 1019,
#                     "name": "\u6e56\u5357"
#                 },
#                 {
#                     "value": 1276,
#                     "name": "\u6cb3\u5357"
#                 },
#                 {
#                     "value": 254,
#                     "name": "\u5e7f\u897f"
#                 },
#                 {
#                     "value": 75,
#                     "name": "\u5b81\u590f"
#                 },
#                 {
#                     "value": 18,
#                     "name": "\u9752\u6d77"
#                 },
#                 {
#                     "value": 1,
#                     "name": "\u897f\u85cf"
#                 }
#             ]
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 6531812,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_8de45c8f695f4014bcf40c30e77d7e35.setOption(option_8de45c8f695f4014bcf40c30e77d7e35);
#
#     });
# </scrip

# %%
start_date = dxy_area['updateTime'][dxy_area.shape[0]-1]
end_date = dxy_area['updateTime'][0]
num_dates = (end_date - start_date).days + 1 
dates = []
delta = timedelta(days=1)
provinces = dxy_area['provinceName']
provinces = provinces.drop_duplicates().reset_index(drop=True)
confirmedSeries = np.zeros((provinces.shape[0], num_dates), dtype=int)
curedSeries = np.zeros((provinces.shape[0], num_dates), dtype=int)
deathSeries = np.zeros((provinces.shape[0], num_dates), dtype=int)

date_idx = 0
while start_date <= end_date:
    for i in range(provinces.shape[0]):
        record = dxy_area.loc[(dxy_area['updateTime'] == start_date) & (dxy_area['provinceName'] == provinces[i])]
        if (record.shape[0] == 1):
            confirmedSeries[i][date_idx] = record['province_confirmedCount']
            curedSeries[i][date_idx] = record['province_curedCount']
            deathSeries[i][date_idx] = record['province_deadCount']
        else:
            confirmedSeries[i][date_idx] = confirmedSeries[i][date_idx - 1]
            curedSeries[i][date_idx] = curedSeries[i][date_idx - 1]
            deathSeries[i][date_idx] = deathSeries[i][date_idx - 1]
    dates.append(start_date)
    start_date += delta
    date_idx += 1

# %%
from pyecharts import Line

# Confirmed Cases Series 
existing = confirmedSeries - curedSeries - deathSeries
existing_all = existing.sum(0)
existing_Hubei = existing[23]
existing_nonHubei = existing_all - existing_Hubei

line = Line("Existing Confirmed Cases")
line.add("China", dates, existing_all, is_smooth=True, mark_point=["max"], 
         mark_point_symbol="diamond", mark_point_textcolor="#40ff27")
line.add("Hubei", dates, existing_Hubei, is_smooth=True, mark_point=["max"], 
         mark_point_symbol="arrow")
line.add("nonHubei", dates, existing_nonHubei, is_smooth=True, mark_point=["max"],
        xaxis_name="date", yaxis_name="Exising Confirmed Cases",
        yaxis_name_gap = 50)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a82796458e884a4196823cc5a6cb165a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a82796458e884a4196823cc5a6cb165a = echarts.init(document.getElementById('a82796458e884a4196823cc5a6cb165a'), 'light', {renderer: 'canvas'});
#
# var option_a82796458e884a4196823cc5a6cb165a = {
#     "yAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "name": "Exising Confirmed Cases",
#             "boundaryGap": true,
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "margin": 8
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "nameLocation": "middle",
#             "show": true,
#             "nameGap": 50,
#             "inverse": false,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "title": [
#         {
#             "left": "auto",
#             "text": "Existing Confirmed Cases",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "China",
#                 "Hubei",
#                 "nonHubei"
#             ],
#             "left": "center",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "symbolSize": 4,
#             "type": "line",
#             "name": "China",
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "data": []
#             },
#             "lineStyle": {
#                 "normal": {
#                     "opacity": 1,
#                     "curveness": 0,
#                     "width": 1,
#                     "type": "solid"
#                 }
#             },
#             "seriesId": 7369048,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#40ff27"
#                                 }
#                             }
#                         },
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "diamond"
#                     }
#                 ]
#             },
#             "step": false,
#             "showSymbol": true,
#             "smooth": true,
#             "symbol": "emptyCircle",
#             "data": [
#                 [
#                     "2020-01-22",
#                     499.0
#                 ],
#                 [
#                     "2020-01-23",
#                     592.0
#                 ],
#                 [
#                     "2020-01-24",
#                     839.0
#                 ],
#                 [
#                     "2020-01-25",
#                     1297.0
#                 ],
#                 [
#                     "2020-01-26",
#                     1971.0
#                 ],
#                 [
#                     "2020-01-27",
#                     2716.0
#                 ],
#                 [
#                     "2020-01-28",
#                     4451.0
#                 ],
#                 [
#                     "2020-01-29",
#                     5843.0
#                 ],
#                 [
#                     "2020-01-30",
#                     7843.0
#                 ],
#                 [
#                     "2020-01-31",
#                     9385.0
#                 ],
#                 [
#                     "2020-02-01",
#                     11367.0
#                 ],
#                 [
#                     "2020-02-02",
#                     13752.0
#                 ],
#                 [
#                     "2020-02-03",
#                     16453.0
#                 ],
#                 [
#                     "2020-02-04",
#                     19386.0
#                 ],
#                 [
#                     "2020-02-05",
#                     22923.0
#                 ],
#                 [
#                     "2020-02-06",
#                     26201.0
#                 ],
#                 [
#                     "2020-02-07",
#                     28874.0
#                 ],
#                 [
#                     "2020-02-08",
#                     31574.0
#                 ],
#                 [
#                     "2020-02-09",
#                     33575.0
#                 ],
#                 [
#                     "2020-02-10",
#                     35802.0
#                 ],
#                 [
#                     "2020-02-11",
#                     37429.0
#                 ],
#                 [
#                     "2020-02-12",
#                     38583.0
#                 ],
#                 [
#                     "2020-02-13",
#                     52324.0
#                 ],
#                 [
#                     "2020-02-14",
#                     55476.0
#                 ],
#                 [
#                     "2020-02-15",
#                     56563.0
#                 ],
#                 [
#                     "2020-02-16",
#                     57165.0
#                 ],
#                 [
#                     "2020-02-17",
#                     57590.0
#                 ],
#                 [
#                     "2020-02-18",
#                     57658.0
#                 ],
#                 [
#                     "2020-02-19",
#                     57335.0
#                 ],
#                 [
#                     "2020-02-20",
#                     55837.0
#                 ],
#                 [
#                     "2020-02-21",
#                     54645.0
#                 ],
#                 [
#                     "2020-02-22",
#                     52973.0
#                 ],
#                 [
#                     "2020-02-23",
#                     51420.0
#                 ],
#                 [
#                     "2020-02-24",
#                     49666.0
#                 ],
#                 [
#                     "2020-02-25",
#                     47464.0
#                 ],
#                 [
#                     "2020-02-26",
#                     45399.0
#                 ],
#                 [
#                     "2020-02-27",
#                     42968.0
#                 ],
#                 [
#                     "2020-02-28",
#                     39859.0
#                 ],
#                 [
#                     "2020-02-29

# %%
from pyecharts import Pie

NorthEast = [25, 22, 17] # 东北地区（3个）：黑龙江、吉林、辽宁
NorthChina = [2, 16, 8, 10, 13] # 华北地区（5个）：北京、天津、河北、山西、内蒙古
CentralChina = [29, 28] # 华中地区（3个）：河南、湖北、湖南 除去湖北
EastChina = [14, 19, 26, 5, 15, 24, 18, 7] # 华东地区（8个）：山东、江苏、安徽、上海、浙江、江西、福建、台湾
SouthChina = [6, 30, 20, 0, 21] # 华南地区（5个）：广东、广西、海南、香港、澳门
NorthWest = [9, 4, 31, 32, 1] # 西北地区（5个）：陕西、甘肃、宁夏、青海、新疆
SouthWest = [3, 27, 11, 12, 33] # 西南地区（5个）：四川、贵州、云南、重庆、西藏

NorthEast_provinces = [province[i] for i in NorthEast]
NorthChina_provinces = [province[i] for i in NorthChina]
CentralChina_provinces = [province[i] for i in CentralChina]
EastChina_provinces = [province[i] for i in EastChina]
SouthChina_provinces = [province[i] for i in SouthChina]
NorthWest_provinces = [province[i] for i in NorthWest]
SouthWest_provinces = [province[i] for i in SouthWest]

NorthEast_cases = [confirmedCount[i] for i in NorthEast]
NorthChina_cases = [confirmedCount[i] for i in NorthChina]
CentralChina_cases = [confirmedCount[i] for i in CentralChina]
EastChina_cases = [confirmedCount[i] for i in EastChina]
SouthChina_cases = [confirmedCount[i] for i in SouthChina]
NorthWest_cases = [confirmedCount[i] for i in NorthWest]
SouthWest_cases = [confirmedCount[i] for i in SouthWest]

region = ['NorthEast', 'NorthChina', 'CentralChina', 'EastChina', 'SouthChina', 'NorthWest', 'SouthWest']
region_cases = [sum(NorthEast_cases), sum(NorthChina_cases), sum(CentralChina_cases), sum(EastChina_cases), 
                sum(SouthChina_cases), sum(NorthWest_cases), sum(SouthWest_cases)]

pie = Pie("Proportion of Confirmed Cases in China")
pie.add(
    "Cumulative Confirmed Cases",
    region,
    region_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="efa836695f7d4667829ad659cce22919" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_efa836695f7d4667829ad659cce22919 = echarts.init(document.getElementById('efa836695f7d4667829ad659cce22919'), 'light', {renderer: 'canvas'});
#
# var option_efa836695f7d4667829ad659cce22919 = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in China",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "NorthEast",
#                 "NorthChina",
#                 "CentralChina",
#                 "EastChina",
#                 "SouthChina",
#                 "NorthWest",
#                 "SouthWest"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 1266,
#                     "name": "NorthEast"
#                 },
#                 {
#                     "value": 1931,
#                     "name": "NorthChina"
#                 },
#                 {
#                     "value": 2295,
#                     "name": "CentralChina"
#                 },
#                 {
#                     "value": 6186,
#                     "name": "EastChina"
#                 },
#                 {
#                     "value": 3776,
#                     "name": "SouthChina"
#                 },
#                 {
#                     "value": 658,
#                     "name": "NorthWest"
#                 },
#                 {
#                     "value": 1518,
#                     "name": "SouthWest"
#                 }
#             ],
#             "seriesId": 7849252
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 7849252,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_efa836695f7d4667829ad659cce22919.setOption(option_efa836695f7d4667829ad659cce22919);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in NorthEast")

pie.add(
    "Cumulative Confirmed Cases",
    NorthEast_provinces,
    NorthEast_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ed7fae0503b4451d94d2d5e973bd405e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ed7fae0503b4451d94d2d5e973bd405e = echarts.init(document.getElementById('ed7fae0503b4451d94d2d5e973bd405e'), 'light', {renderer: 'canvas'});
#
# var option_ed7fae0503b4451d94d2d5e973bd405e = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in NorthEast",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5409\u6797",
#                 "\u8fbd\u5b81"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 947,
#                     "name": "\u9ed1\u9f99\u6c5f"
#                 },
#                 {
#                     "value": 155,
#                     "name": "\u5409\u6797"
#                 },
#                 {
#                     "value": 164,
#                     "name": "\u8fbd\u5b81"
#                 }
#             ],
#             "seriesId": 2773715
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 2773715,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_ed7fae0503b4451d94d2d5e973bd405e.setOption(option_ed7fae0503b4451d94d2d5e973bd405e);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in NorthChina")

pie.add(
    "Cumulative Confirmed Cases",
    NorthChina_provinces,
    NorthChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="eb0120ec37f341da8b087ad563877989" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_eb0120ec37f341da8b087ad563877989 = echarts.init(document.getElementById('eb0120ec37f341da8b087ad563877989'), 'light', {renderer: 'canvas'});
#
# var option_eb0120ec37f341da8b087ad563877989 = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in NorthChina",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u5317\u4eac",
#                 "\u5929\u6d25",
#                 "\u6cb3\u5317",
#                 "\u5c71\u897f",
#                 "\u5185\u8499\u53e4"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 929,
#                     "name": "\u5317\u4eac"
#                 },
#                 {
#                     "value": 203,
#                     "name": "\u5929\u6d25"
#                 },
#                 {
#                     "value": 349,
#                     "name": "\u6cb3\u5317"
#                 },
#                 {
#                     "value": 201,
#                     "name": "\u5c71\u897f"
#                 },
#                 {
#                     "value": 249,
#                     "name": "\u5185\u8499\u53e4"
#                 }
#             ],
#             "seriesId": 1176092
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 1176092,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_eb0120ec37f341da8b087ad563877989.setOption(option_eb0120ec37f341da8b087ad563877989);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in CentralChina (except Hubei)")

pie.add(
    "Cumulative Confirmed Cases",
    CentralChina_provinces,
    CentralChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="145cefff58fd473982285f21ebac1123" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_145cefff58fd473982285f21ebac1123 = echarts.init(document.getElementById('145cefff58fd473982285f21ebac1123'), 'light', {renderer: 'canvas'});
#
# var option_145cefff58fd473982285f21ebac1123 = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in CentralChina (except Hubei)",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u6cb3\u5357",
#                 "\u6e56\u5357"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 1276,
#                     "name": "\u6cb3\u5357"
#                 },
#                 {
#                     "value": 1019,
#                     "name": "\u6e56\u5357"
#                 }
#             ],
#             "seriesId": 2752219
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 2752219,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_145cefff58fd473982285f21ebac1123.setOption(option_145cefff58fd473982285f21ebac1123);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in EastChina")

pie.add(
    "Cumulative Confirmed Cases",
    EastChina_provinces,
    EastChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f90f28ba4ddc4bd38afe288e7d7c26ed" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f90f28ba4ddc4bd38afe288e7d7c26ed = echarts.init(document.getElementById('f90f28ba4ddc4bd38afe288e7d7c26ed'), 'light', {renderer: 'canvas'});
#
# var option_f90f28ba4ddc4bd38afe288e7d7c26ed = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in EastChina",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u5c71\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u5b89\u5fbd",
#                 "\u4e0a\u6d77",
#                 "\u6d59\u6c5f",
#                 "\u6c5f\u897f",
#                 "\u798f\u5efa",
#                 "\u53f0\u6e7e"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 793,
#                     "name": "\u5c71\u4e1c"
#                 },
#                 {
#                     "value": 654,
#                     "name": "\u6c5f\u82cf"
#                 },
#                 {
#                     "value": 991,
#                     "name": "\u5b89\u5fbd"
#                 },
#                 {
#                     "value": 732,
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "value": 1270,
#                     "name": "\u6d59\u6c5f"
#                 },
#                 {
#                     "value": 932,
#                     "name": "\u6c5f\u897f"
#                 },
#                 {
#                     "value": 363,
#                     "name": "\u798f\u5efa"
#                 },
#                 {
#                     "value": 451,
#                     "name": "\u53f0\u6e7e"
#                 }
#             ],
#             "seriesId": 3300286
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 3300286,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_f90f28ba4ddc4bd38afe288e7d7c26ed.setOption(option_f90f28ba4ddc4bd38afe288e7d7c26ed);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in SouthChina")

pie.add(
    "Cumulative Confirmed Cases",
    SouthChina_provinces,
    SouthChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5576d31e6a244ef398db9a447b3bbfe9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5576d31e6a244ef398db9a447b3bbfe9 = echarts.init(document.getElementById('5576d31e6a244ef398db9a447b3bbfe9'), 'light', {renderer: 'canvas'});
#
# var option_5576d31e6a244ef398db9a447b3bbfe9 = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in SouthChina",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u6d77\u5357",
#                 "\u9999\u6e2f",
#                 "\u6fb3\u95e8"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 1650,
#                     "name": "\u5e7f\u4e1c"
#                 },
#                 {
#                     "value": 254,
#                     "name": "\u5e7f\u897f"
#                 },
#                 {
#                     "value": 171,
#                     "name": "\u6d77\u5357"
#                 },
#                 {
#                     "value": 1655,
#                     "name": "\u9999\u6e2f"
#                 },
#                 {
#                     "value": 46,
#                     "name": "\u6fb3\u95e8"
#                 }
#             ],
#             "seriesId": 3886617
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 3886617,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_5576d31e6a244ef398db9a447b3bbfe9.setOption(option_5576d31e6a244ef398db9a447b3bbfe9);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in NorthWest")

pie.add(
    "Cumulative Confirmed Cases",
    NorthWest_provinces,
    NorthWest_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="50b44c5303684a8e8e37e82d1dd7ff9b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_50b44c5303684a8e8e37e82d1dd7ff9b = echarts.init(document.getElementById('50b44c5303684a8e8e37e82d1dd7ff9b'), 'light', {renderer: 'canvas'});
#
# var option_50b44c5303684a8e8e37e82d1dd7ff9b = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in NorthWest",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u9655\u897f",
#                 "\u7518\u8083",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u65b0\u7586"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 321,
#                     "name": "\u9655\u897f"
#                 },
#                 {
#                     "value": 167,
#                     "name": "\u7518\u8083"
#                 },
#                 {
#                     "value": 75,
#                     "name": "\u5b81\u590f"
#                 },
#                 {
#                     "value": 18,
#                     "name": "\u9752\u6d77"
#                 },
#                 {
#                     "value": 77,
#                     "name": "\u65b0\u7586"
#                 }
#             ],
#             "seriesId": 3021606
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 3021606,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_50b44c5303684a8e8e37e82d1dd7ff9b.setOption(option_50b44c5303684a8e8e37e82d1dd7ff9b);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in SouthWest")

pie.add(
    "Cumulative Confirmed Cases",
    SouthWest_provinces,
    SouthWest_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5ba7efcf51c047bca2b393ed03715834" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5ba7efcf51c047bca2b393ed03715834 = echarts.init(document.getElementById('5ba7efcf51c047bca2b393ed03715834'), 'light', {renderer: 'canvas'});
#
# var option_5ba7efcf51c047bca2b393ed03715834 = {
#     "title": [
#         {
#             "left": "auto",
#             "text": "Proportion of Confirmed Cases in SouthWest",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "orient": "vertical",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u56db\u5ddd",
#                 "\u8d35\u5dde",
#                 "\u4e91\u5357",
#                 "\u91cd\u5e86",
#                 "\u897f\u85cf"
#             ],
#             "left": "right",
#             "selectedMode": "multiple"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "type": "pie",
#             "name": "Cumulative Confirmed Cases",
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "data": [
#                 {
#                     "value": 599,
#                     "name": "\u56db\u5ddd"
#                 },
#                 {
#                     "value": 147,
#                     "name": "\u8d35\u5dde"
#                 },
#                 {
#                     "value": 188,
#                     "name": "\u4e91\u5357"
#                 },
#                 {
#                     "value": 583,
#                     "name": "\u91cd\u5e86"
#                 },
#                 {
#                     "value": 1,
#                     "name": "\u897f\u85cf"
#                 }
#             ],
#             "seriesId": 6310654
#         }
#     ],
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "series_id": 6310654,
#     "animation": true,
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     }
# };
# myChart_5ba7efcf51c047bca2b393ed03715834.setOption(option_5ba7efcf51c047bca2b393ed03715834);
#
#     });
# </script>

# %%
from pyecharts import Scatter, Grid

scatter = Scatter("Quadrant Chart of Weekly Growth Rate & Current Confirmed Cases on 2.11")
for i in range(len(province)): 
    if i != 23:
        scatter.add(
            province[i], 
            [confirmedSeries[i, 20]], 
            [(confirmedSeries[i, 20] - confirmedSeries[i, 13]) / confirmedSeries[i, 13]], 
            xaxis_name="Current Confirmed Cases",
            yaxis_name="Weekly Growth Rate",
            legend_top="10%")

g = Grid(width=800, height=600)
g.add(scatter, grid_top="25%")
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="018a556dad6c4afd9983ee4e4b28aca7" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_018a556dad6c4afd9983ee4e4b28aca7 = echarts.init(document.getElementById('018a556dad6c4afd9983ee4e4b28aca7'), 'light', {renderer: 'canvas'});
#
# var option_018a556dad6c4afd9983ee4e4b28aca7 = {
#     "series": [
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u9999\u6e2f",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     49.0,
#                     1.8823529411764706
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u65b0\u7586",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     55.0,
#                     0.896551724137931
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u5317\u4eac",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     342.0,
#                     0.5
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u56db\u5ddd",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     417.0,
#                     0.4787234042553192
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u7518\u8083",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     86.0,
#                     0.5087719298245614
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u4e0a\u6d77",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     303.0,
#                     0.3835616438356164
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u5e7f\u4e1c",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     1177.0,
#                     0.44772447724477243
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u53f0\u6e7e",
#             "seriesId": 4559803,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     18.0,
#                     0.6363636363636364
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12

# %%
province_population = pd.read_csv('population_province.csv', header=0, sep=',')
transporation = pd.read_csv('transportation_hubei2province.csv', header=0, sep=',')
transporation['date'] = pd.to_datetime(transporation.date).dt.date

# %%
population = np.zeros(provinces.shape[0], dtype=float)
for i in range(provinces.shape[0]):
    record = province_population[province_population['provinceName'] == province[i]]
    population[i] = record['population'].values[0]

# %%
start_date = date(2020, 1, 1)
end_date =  date(2020, 2, 3)
num_dates = (end_date - start_date).days + 1 
delta = timedelta(days=1)

passengers = np.zeros(provinces.shape[0], dtype=float)
num_records = np.zeros(provinces.shape[0], dtype=int)

while start_date <= end_date:
    for i in range(provinces.shape[0]):
        record = transporation.loc[(transporation['date'] == start_date) & (transporation['provinceName'] == current['provinceName'][i])]
        if (record.shape[0] == 1):
            passengers[i] += record['passenger'].values[0]
#             print(start_date, current['provinceName'][i], record['passenger'].values[0])
            num_records[i] += 1
    start_date += delta

for i in range(provinces.shape[0]):  
    passengers[i] /= num_records[i]

# %%
validTransporationIdx = ~np.isnan(passengers)
validTransporationIdx[23] = False

sc = Scatter("Relationship between Population, Transportation and Confirmed Cases")
for i in range(len(province)):
    if validTransporationIdx[i]:
        sc.add(
            province[i],
            [population[i]],
            [passengers[i]],
            extra_data=[confirmedSeries[i, 12]],
            is_visualmap=True,
            visual_dimension=2,
            visual_orient="horizontal",
            visual_type="size",
            visual_range=[0, 724],
            visual_text_color="#000",
            legend_top="10%",
            xaxis_name="Annual permanent population (10,000 people)",
            yaxis_name="Passengers from Wuhan per day",
            yaxis_name_gap = 50
        )
        
g = Grid(width=800, height=600)
g.add(sc, grid_top="25%")
g
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="72952acf4f1d41cdb3ead88346c0f8df" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_72952acf4f1d41cdb3ead88346c0f8df = echarts.init(document.getElementById('72952acf4f1d41cdb3ead88346c0f8df'), 'light', {renderer: 'canvas'});
#
# var option_72952acf4f1d41cdb3ead88346c0f8df = {
#     "visualMap": {
#         "orient": "horizontal",
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "type": "continuous",
#         "dimension": 2,
#         "max": 724,
#         "left": "left",
#         "text": [
#             "high",
#             "low"
#         ],
#         "calculable": true,
#         "top": "bottom",
#         "showLabel": true,
#         "textStyle": {
#             "color": "#000"
#         },
#         "splitNumber": 5,
#         "min": 0
#     },
#     "series": [
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u65b0\u7586",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     2487.0,
#                     121.55731655294115,
#                     24.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u5317\u4eac",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     2154.0,
#                     550.4400922705883,
#                     212.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u56db\u5ddd",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     8341.0,
#                     615.9983618235293,
#                     254.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u7518\u8083",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     2637.0,
#                     186.7966729411765,
#                     51.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u4e0a\u6d77",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     2424.0,
#                     410.51811928235287,
#                     203.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u5e7f\u4e1c",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     11346.0,
#                     1115.6180972823524,
#                     725.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name": "\u6cb3\u5317",
#             "seriesId": 19637,
#             "type": "scatter",
#             "symbol": "circle",
#             "markLine": {
#                 "data": []
#             },
#             "data": [
#                 [
#                     7556.0,
#                     462.9804098882352,
#                     113.0
#                 ]
#             ]
#         },
#         {
#             "symbolSize": 10,
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "name"
