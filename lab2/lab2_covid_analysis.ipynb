# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
import warnings
warnings.filterwarnings('ignore')

# %%
# preprocessing data
dxy_area = pd.read_csv('DXYArea.csv')
dxy_area = dxy_area[ (dxy_area.countryName == '中国') & (dxy_area.provinceName != '中国')]
dxy_area['updateTime'] = pd.to_datetime(dxy_area.updateTime).dt.date
dxy_area = dxy_area.drop_duplicates(['provinceName','updateTime']).reset_index(drop=True)
dxy_area = dxy_area[['provinceName','province_confirmedCount','province_curedCount','province_deadCount','updateTime']]

# %%
current = dxy_area.drop_duplicates(['provinceName']).reset_index(drop=True)
current['provinceName'][0] = '香港'
current['provinceName'][1] = '新疆'
current['provinceName'][2] = '北京'
current['provinceName'][3] = '四川'
current['provinceName'][4] = '甘肃'
current['provinceName'][5] = '上海'
current['provinceName'][6] = '广东'
current['provinceName'][7] = '台湾'
current['provinceName'][8] = '河北'
current['provinceName'][9] = '陕西'
current['provinceName'][10] = '山西'
current['provinceName'][11] = '云南'
current['provinceName'][12] = '重庆'
current['provinceName'][13] = '内蒙古'
current['provinceName'][14] = '山东'
current['provinceName'][15] = '浙江'
current['provinceName'][16] = '天津'
current['provinceName'][17] = '辽宁'
current['provinceName'][18] = '福建'
current['provinceName'][19] = '江苏'
current['provinceName'][20] = '海南'
current['provinceName'][21] = '澳门'
current['provinceName'][22] = '吉林'
current['provinceName'][23] = '湖北'
current['provinceName'][24] = '江西'
current['provinceName'][25] = '黑龙江'
current['provinceName'][26] = '安徽'
current['provinceName'][27] = '贵州'
current['provinceName'][28] = '湖南'
current['provinceName'][29] = '河南'
current['provinceName'][30] = '广西'
current['provinceName'][31] = '宁夏'
current['provinceName'][32] = '青海'
current['provinceName'][33] = '西藏'
current
# Out:
#    provinceName  province_confirmedCount  province_curedCount  \
# 0            香港                     1655                 1254
# 1            新疆                       77                   73
# 2            北京                      929                  752
# 3            四川                      599                  590
# 4            甘肃                      167                  165
# 5            上海                      732                  691
# 6            广东                     1650                 1636
# 7            台湾                      451                  440
# 8            河北                      349                  340
# 9            陕西                      321                  315
# 10           山西                      201                  198
# 11           云南                      188                  183
# 12           重庆                      583                  576
# 13          内蒙古                      249                  237
# 14           山东                      793                  785
# 15           浙江                     1270                 1267
# 16           天津                      203                  195
# 17           辽宁                      164                  150
# 18           福建                      363                  361
# 19           江苏                      654                  654
# 20           海南                      171                  165
# 21           澳门                       46                   45
# 22           吉林                      155                  153
# 23           湖北                    68135                63623
# 24           江西                      932                  931
# 25          黑龙江                      947                  934
# 26           安徽                      991                  985
# 27           贵州                      147                  145
# 28           湖南                     1019                 1015
# 29           河南                     1276                 1254
# 30           广西                      254                  252
# 31           宁夏                       75                   75
# 32           青海                       18                   18
# 33           西藏                        1                    1
#
#     province_deadCount  updateTime
# 0                   10  2020-07-16
# 1                    3  2020-07-16
# 2                    9  2020-07-16
# 3                    3  2020-07-16
# 4                    2  2020-07-16
# 5                    7  2020-07-16
# 6                    8  2020-07-15
# 7                    7  2020-07-15
# 8                    6  2020-07-15
# 9                    3  2020-07-15
# 10                   0  2020-07-15
# 11                   2  2020-07-15
# 12                   6  2020-07-15
# 13                   1  2020-07-13
# 14                   7  2020-07-13
# 15                   1  2020-07-12
# 16                   3  2020-07-12
# 17                   2  2020-07-11
# 18                   1  2020-07-11
# 19                   0  2020-06-30
# 20                   6  2020-06-26
# 21                   0  2020-06-26
# 22                   2  2020-06-07
# 23                4512  2020-06-05
# 24                   1  2020-06-03
# 25                  13  2020-06-03
# 26                   6  2020-04-24
# 27                   2  2020-04-19
# 28                   4  2020-04-18
# 29                  22  2020-04-14
# 30                   2  2020-04-02
# 31                   0  2020-03-16
# 32                   0  2020-02-23
# 33                   0  2020-02-23

# %%
from pyecharts import Map

province = current['provinceName'].values.tolist()
confirmedCount = current['province_confirmedCount'].values.tolist()
# print(len(province), len(confirmedCount))

map = Map("Cumulative Confirmed Cases in China", '', width=1200, height=600)

range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
map.add("Confirmed Cases", province, confirmedCount, visual_range=[0, 2000], maptype='china', is_visualmap=True, visual_range_color=range_color, visual_text_color='#000', is_map_symbol_show=False, is_label_show=True)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="d1a2c661a4184707aa6d17ee33a978b4" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_d1a2c661a4184707aa6d17ee33a978b4 = echarts.init(document.getElementById('d1a2c661a4184707aa6d17ee33a978b4'), 'light', {renderer: 'canvas'});
#
# var option_d1a2c661a4184707aa6d17ee33a978b4 = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 8286237,
#     "series": [
#         {
#             "type": "map",
#             "roam": true,
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "name": "Confirmed Cases",
#             "symbol": "circle",
#             "mapType": "china",
#             "showLegendSymbol": false,
#             "data": [
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1655
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 929
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 599
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 167
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 732
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1650
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 451
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 349
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 321
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 201
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 583
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 249
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 793
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1270
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 203
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 164
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 363
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 654
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 171
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 68135
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 932
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 947
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 991
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1019
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1276
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 254
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "orient": "vertical",
#         "text": [
#             "high",
#             "low"
#         ],
#         "showLabel": true,
#         "type": "continuous",
#         "min": 0,
#         "left": "left",
#         "max": 2000,
#         "splitNumber": 5,
#         "calculable": true,
#         "textStyle": {
#             "color": "#000"
#         },
#         "inRange": {
#             "color": [
#                 "#313695",
#                 "#4575b4",
#                 "#74add1",
#                 "#abd9e9",
#                 "#e0f3f8",
#                 "#ffffbf",
#                 "#fee090",
#                 "#fdae61",
#                 "#f46d43",
#                 "#d73027",
#                 "#a50026"
#             ]
#         },
#         "top": "bottom"
#     },
#     "legend": [
#         {
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "Confirmed Cases"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Cumulative Confirmed Cases in China"
#         }
#     ]
# };
# myChart_d1a2c661a4184707aa6d17ee33a978b4.setOption(option_d1a2c661a4184707aa6d17ee33a978b4);
#
#     });
# </scrip

# %%
start_date = dxy_area['updateTime'][dxy_area.shape[0]-1]
end_date = dxy_area['updateTime'][0]
num_dates = (end_date - start_date).days + 1 
dates = []
delta = timedelta(days=1)
provinces = dxy_area['provinceName']
provinces = provinces.drop_duplicates().reset_index(drop=True)
confirmedSeries = np.zeros((provinces.shape[0], num_dates), dtype=int)
curedSeries = np.zeros((provinces.shape[0], num_dates), dtype=int)
deathSeries = np.zeros((provinces.shape[0], num_dates), dtype=int)

date_idx = 0
while start_date <= end_date:
    for i in range(provinces.shape[0]):
        record = dxy_area.loc[(dxy_area['updateTime'] == start_date) & (dxy_area['provinceName'] == provinces[i])]
        if (record.shape[0] == 1):
            confirmedSeries[i][date_idx] = record['province_confirmedCount']
            curedSeries[i][date_idx] = record['province_curedCount']
            deathSeries[i][date_idx] = record['province_deadCount']
        else:
            confirmedSeries[i][date_idx] = confirmedSeries[i][date_idx - 1]
            curedSeries[i][date_idx] = curedSeries[i][date_idx - 1]
            deathSeries[i][date_idx] = deathSeries[i][date_idx - 1]
    dates.append(start_date)
    start_date += delta
    date_idx += 1

# %%
from pyecharts import Line

# Confirmed Cases Series 
existing_all = confirmedSeries.sum(0) - curedSeries.sum(0) - deathSeries.sum(0)
existing_Hubei = confirmedSeries[23] - curedSeries[23] - deathSeries[23]
existing_nonHubei = existing_all - existing_Hubei

line = Line("Existing Confirmed Cases")
line.add("China", dates, existing_all, is_smooth=True, mark_point=["max"], 
         mark_point_symbol="diamond", mark_point_textcolor="#40ff27")
line.add("Hubei", dates, existing_Hubei, is_smooth=True, mark_point=["max"], 
         mark_point_symbol="arrow")
line.add("nonHubei", dates, existing_nonHubei, is_smooth=True, mark_point=["max"])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="96b19adcc4dc49a1bf313e0d8c3c7aa7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_96b19adcc4dc49a1bf313e0d8c3c7aa7 = echarts.init(document.getElementById('96b19adcc4dc49a1bf313e0d8c3c7aa7'), 'light', {renderer: 'canvas'});
#
# var option_96b19adcc4dc49a1bf313e0d8c3c7aa7 = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "xAxis": [
#         {
#             "boundaryGap": true,
#             "inverse": false,
#             "show": true,
#             "type": "category",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameGap": 25,
#             "splitLine": {
#                 "show": false
#             },
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "data": [
#                 "2020-01-22",
#                 "2020-01-23",
#                 "2020-01-24",
#                 "2020-01-25",
#                 "2020-01-26",
#                 "2020-01-27",
#                 "2020-01-28",
#                 "2020-01-29",
#                 "2020-01-30",
#                 "2020-01-31",
#                 "2020-02-01",
#                 "2020-02-02",
#                 "2020-02-03",
#                 "2020-02-04",
#                 "2020-02-05",
#                 "2020-02-06",
#                 "2020-02-07",
#                 "2020-02-08",
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18",
#                 "2020-02-19",
#                 "2020-02-20",
#                 "2020-02-21",
#                 "2020-02-22",
#                 "2020-02-23",
#                 "2020-02-24",
#                 "2020-02-25",
#                 "2020-02-26",
#                 "2020-02-27",
#                 "2020-02-28",
#                 "2020-02-29",
#                 "2020-03-01",
#                 "2020-03-02",
#                 "2020-03-03",
#                 "2020-03-04",
#                 "2020-03-05",
#                 "2020-03-06",
#                 "2020-03-07",
#                 "2020-03-08",
#                 "2020-03-09",
#                 "2020-03-10",
#                 "2020-03-11",
#                 "2020-03-12",
#                 "2020-03-13",
#                 "2020-03-14",
#                 "2020-03-15",
#                 "2020-03-16",
#                 "2020-03-17",
#                 "2020-03-18",
#                 "2020-03-19",
#                 "2020-03-20",
#                 "2020-03-21",
#                 "2020-03-22",
#                 "2020-03-23",
#                 "2020-03-24",
#                 "2020-03-25",
#                 "2020-03-26",
#                 "2020-03-27",
#                 "2020-03-28",
#                 "2020-03-29",
#                 "2020-03-30",
#                 "2020-03-31",
#                 "2020-04-01",
#                 "2020-04-02",
#                 "2020-04-03",
#                 "2020-04-04",
#                 "2020-04-05",
#                 "2020-04-06",
#                 "2020-04-07",
#                 "2020-04-08",
#                 "2020-04-09",
#                 "2020-04-10",
#                 "2020-04-11",
#                 "2020-04-12",
#                 "2020-04-13",
#                 "2020-04-14",
#                 "2020-04-15",
#                 "2020-04-16",
#                 "2020-04-17",
#                 "2020-04-18",
#                 "2020-04-19",
#                 "2020-04-20",
#                 "2020-04-21",
#                 "2020-04-22",
#                 "2020-04-23",
#                 "2020-04-24",
#                 "2020-04-25",
#                 "2020-04-26",
#                 "2020-04-27",
#                 "2020-04-28",
#                 "2020-04-29",
#                 "2020-04-30",
#                 "2020-05-01",
#                 "2020-05-02",
#                 "2020-05-03",
#                 "2020-05-04",
#                 "2020-05-05",
#                 "2020-05-06",
#                 "2020-05-07",
#                 "2020-05-08",
#                 "2020-05-09",
#                 "2020-05-10",
#                 "2020-05-11",
#                 "2020-05-12",
#                 "2020-05-13",
#                 "2020-05-14",
#                 "2020-05-15",
#                 "2020-05-16",
#                 "2020-05-17",
#                 "2020-05-18",
#                 "2020-05-19",
#                 "2020-05-20",
#                 "2020-05-21",
#                 "2020-05-22",
#                 "2020-05-23",
#                 "2020-05-24",
#                 "2020-05-25",
#                 "2020-05-26",
#                 "2020-05-27",
#                 "2020-05-28",
#                 "2020-05-29",
#                 "2020-05-30",
#                 "2020-05-31",
#                 "2020-06-01",
#                 "2020-06-02",
#                 "2020-06-03",
#                 "2020-06-04",
#                 "2020-06-05",
#                 "2020-06-06",
#                 "2020-06-07",
#                 "2020-06-08",
#                 "2020-06-09",
#                 "2020-06-10",
#                 "2020-06-11",
#                 "2020-06-12",
#                 "2020-06-13",
#                 "2020-06-14",
#                 "2020-06-15",
#                 "2020-06-16",
#                 "2020-06-17",
#                 "2020-06-18",
#                 "2020-06-19",
#                 "2020-06-20",
#                 "2020-06-21",
#                 "2020-06-22",
#                 "2020-06-23",
#                 "2020-06-24",
#                 "2020-06-25",
#                 "2020-06-26",
#                 "2020-06-27",
#                 "2020-06-28",
#                 "2020-06-29",
#                 "2020-06-30",
#                 "2020-07-01",
#                 "2020-07-02",
#                 "2020-07-03",
#                 "2020-07-04",
#                 "2020-07-05",
#                 "2020-07-06",
#                 "2020-07-07",
#                 "2020-07-08",
#                 "2020-07-09",
#                 "2020-07-10",
#                 "2020-07-11",
#                 "2020-07-12",
#                 "2020-07-13",
#                 "2020-07-14",
#                 "2020-07-15",
#                 "2020-07-16"
#             ],
#             "axisLabel": {
#                 "rotate": 0,
#                 "interval": "auto",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "series_id": 5990400,
#     "legend": [
#         {
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "China",
#                 "Hubei",
#                 "nonHubei"
#             ]
#         }
#     ],
#     "series": [
#         {
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "name": "China",
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "smooth": true,
#             "symbolSize": 4,
#             "markP

# %%
from pyecharts import Pie

NorthEast = [25, 22, 17] # 东北地区（3个）：黑龙江、吉林、辽宁
NorthChina = [2, 16, 8, 10, 13] # 华北地区（5个）：北京、天津、河北、山西、内蒙古
CentralChina = [29, 28] # 华中地区（3个）：河南、湖北、湖南 除去湖北
EastChina = [14, 19, 26, 5, 15, 24, 18, 7] # 华东地区（8个）：山东、江苏、安徽、上海、浙江、江西、福建、台湾
SouthChina = [6, 30, 20, 0, 21] # 华南地区（5个）：广东、广西、海南、香港、澳门
NorthWest = [9, 4, 31, 32, 1] # 西北地区（5个）：陕西、甘肃、宁夏、青海、新疆
SouthWest = [3, 27, 11, 12, 33] # 西南地区（5个）：四川、贵州、云南、重庆、西藏

NorthEast_provinces = [province[i] for i in NorthEast]
NorthChina_provinces = [province[i] for i in NorthChina]
CentralChina_provinces = [province[i] for i in CentralChina]
EastChina_provinces = [province[i] for i in EastChina]
SouthChina_provinces = [province[i] for i in SouthChina]
NorthWest_provinces = [province[i] for i in NorthWest]
SouthWest_provinces = [province[i] for i in SouthWest]

NorthEast_cases = [confirmedCount[i] for i in NorthEast]
NorthChina_cases = [confirmedCount[i] for i in NorthChina]
CentralChina_cases = [confirmedCount[i] for i in CentralChina]
EastChina_cases = [confirmedCount[i] for i in EastChina]
SouthChina_cases = [confirmedCount[i] for i in SouthChina]
NorthWest_cases = [confirmedCount[i] for i in NorthWest]
SouthWest_cases = [confirmedCount[i] for i in SouthWest]

region = ['NorthEast', 'NorthChina', 'CentralChina', 'EastChina', 'SouthChina', 'NorthWest', 'SouthWest']
region_cases = [sum(NorthEast_cases), sum(NorthChina_cases), sum(CentralChina_cases), sum(EastChina_cases), 
                sum(SouthChina_cases), sum(NorthWest_cases), sum(SouthWest_cases)]

pie = Pie("Proportion of Confirmed Cases in China")
pie.add(
    "Cumulative Confirmed Cases",
    region,
    region_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="79b1cdc3c3dc4b669c462cf2947d290b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_79b1cdc3c3dc4b669c462cf2947d290b = echarts.init(document.getElementById('79b1cdc3c3dc4b669c462cf2947d290b'), 'light', {renderer: 'canvas'});
#
# var option_79b1cdc3c3dc4b669c462cf2947d290b = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 2377055,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 2377055,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "NorthEast",
#                     "value": 1266
#                 },
#                 {
#                     "name": "NorthChina",
#                     "value": 1931
#                 },
#                 {
#                     "name": "CentralChina",
#                     "value": 2295
#                 },
#                 {
#                     "name": "EastChina",
#                     "value": 6186
#                 },
#                 {
#                     "name": "SouthChina",
#                     "value": 3776
#                 },
#                 {
#                     "name": "NorthWest",
#                     "value": 658
#                 },
#                 {
#                     "name": "SouthWest",
#                     "value": 1518
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "NorthEast",
#                 "NorthChina",
#                 "CentralChina",
#                 "EastChina",
#                 "SouthChina",
#                 "NorthWest",
#                 "SouthWest"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in China"
#         }
#     ]
# };
# myChart_79b1cdc3c3dc4b669c462cf2947d290b.setOption(option_79b1cdc3c3dc4b669c462cf2947d290b);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in NorthEast")

pie.add(
    "Cumulative Confirmed Cases",
    NorthEast_provinces,
    NorthEast_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="90f310d7e3134e52938da20a561e2941" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_90f310d7e3134e52938da20a561e2941 = echarts.init(document.getElementById('90f310d7e3134e52938da20a561e2941'), 'light', {renderer: 'canvas'});
#
# var option_90f310d7e3134e52938da20a561e2941 = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 4015364,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 4015364,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 947
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 164
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5409\u6797",
#                 "\u8fbd\u5b81"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in NorthEast"
#         }
#     ]
# };
# myChart_90f310d7e3134e52938da20a561e2941.setOption(option_90f310d7e3134e52938da20a561e2941);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in NorthChina")

pie.add(
    "Cumulative Confirmed Cases",
    NorthChina_provinces,
    NorthChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5b5515685a434693a6413c034ae8e6ce" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5b5515685a434693a6413c034ae8e6ce = echarts.init(document.getElementById('5b5515685a434693a6413c034ae8e6ce'), 'light', {renderer: 'canvas'});
#
# var option_5b5515685a434693a6413c034ae8e6ce = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 3857500,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 3857500,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 929
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 203
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 349
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 201
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 249
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u5317\u4eac",
#                 "\u5929\u6d25",
#                 "\u6cb3\u5317",
#                 "\u5c71\u897f",
#                 "\u5185\u8499\u53e4"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in NorthChina"
#         }
#     ]
# };
# myChart_5b5515685a434693a6413c034ae8e6ce.setOption(option_5b5515685a434693a6413c034ae8e6ce);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in CentralChina (except Hubei)")

pie.add(
    "Cumulative Confirmed Cases",
    CentralChina_provinces,
    CentralChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3af90203a29d4267918cdaaa44832adb" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3af90203a29d4267918cdaaa44832adb = echarts.init(document.getElementById('3af90203a29d4267918cdaaa44832adb'), 'light', {renderer: 'canvas'});
#
# var option_3af90203a29d4267918cdaaa44832adb = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 1319871,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 1319871,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1276
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1019
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u6cb3\u5357",
#                 "\u6e56\u5357"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in CentralChina (except Hubei)"
#         }
#     ]
# };
# myChart_3af90203a29d4267918cdaaa44832adb.setOption(option_3af90203a29d4267918cdaaa44832adb);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in EastChina")

pie.add(
    "Cumulative Confirmed Cases",
    EastChina_provinces,
    EastChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4c3ef1ea99044e58a7a0bad51bd6c104" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4c3ef1ea99044e58a7a0bad51bd6c104 = echarts.init(document.getElementById('4c3ef1ea99044e58a7a0bad51bd6c104'), 'light', {renderer: 'canvas'});
#
# var option_4c3ef1ea99044e58a7a0bad51bd6c104 = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 6816991,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 6816991,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 793
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 654
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 991
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 732
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1270
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 932
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 363
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 451
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u5c71\u4e1c",
#                 "\u6c5f\u82cf",
#                 "\u5b89\u5fbd",
#                 "\u4e0a\u6d77",
#                 "\u6d59\u6c5f",
#                 "\u6c5f\u897f",
#                 "\u798f\u5efa",
#                 "\u53f0\u6e7e"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in EastChina"
#         }
#     ]
# };
# myChart_4c3ef1ea99044e58a7a0bad51bd6c104.setOption(option_4c3ef1ea99044e58a7a0bad51bd6c104);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in SouthChina")

pie.add(
    "Cumulative Confirmed Cases",
    SouthChina_provinces,
    SouthChina_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="403cd9fe1e2145b390693294e51ab85b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_403cd9fe1e2145b390693294e51ab85b = echarts.init(document.getElementById('403cd9fe1e2145b390693294e51ab85b'), 'light', {renderer: 'canvas'});
#
# var option_403cd9fe1e2145b390693294e51ab85b = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 8903006,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 8903006,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1650
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 254
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 171
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1655
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 46
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u6d77\u5357",
#                 "\u9999\u6e2f",
#                 "\u6fb3\u95e8"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in SouthChina"
#         }
#     ]
# };
# myChart_403cd9fe1e2145b390693294e51ab85b.setOption(option_403cd9fe1e2145b390693294e51ab85b);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in NorthWest")

pie.add(
    "Cumulative Confirmed Cases",
    NorthWest_provinces,
    NorthWest_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="85b5fc22b88146dd8f02327e69fdfdfa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_85b5fc22b88146dd8f02327e69fdfdfa = echarts.init(document.getElementById('85b5fc22b88146dd8f02327e69fdfdfa'), 'light', {renderer: 'canvas'});
#
# var option_85b5fc22b88146dd8f02327e69fdfdfa = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 1960443,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 1960443,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 321
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 167
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 77
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u9655\u897f",
#                 "\u7518\u8083",
#                 "\u5b81\u590f",
#                 "\u9752\u6d77",
#                 "\u65b0\u7586"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in NorthWest"
#         }
#     ]
# };
# myChart_85b5fc22b88146dd8f02327e69fdfdfa.setOption(option_85b5fc22b88146dd8f02327e69fdfdfa);
#
#     });
# </script>

# %%
pie = Pie("Proportion of Confirmed Cases in SouthWest")

pie.add(
    "Cumulative Confirmed Cases",
    SouthWest_provinces,
    SouthWest_cases,
    radius=[0, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="right",
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="af277015047c4434836e572254ce9bb9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_af277015047c4434836e572254ce9bb9 = echarts.init(document.getElementById('af277015047c4434836e572254ce9bb9'), 'light', {renderer: 'canvas'});
#
# var option_af277015047c4434836e572254ce9bb9 = {
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "borderColor": "#333"
#     },
#     "series_id": 3765176,
#     "series": [
#         {
#             "type": "pie",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "name": "Cumulative Confirmed Cases",
#             "seriesId": 3765176,
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "data": [
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 599
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 583
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ]
#         }
#     ],
#     "animation": true,
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "left": "right",
#             "orient": "vertical",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "show": true,
#             "selectedMode": "multiple",
#             "data": [
#                 "\u56db\u5ddd",
#                 "\u8d35\u5dde",
#                 "\u4e91\u5357",
#                 "\u91cd\u5e86",
#                 "\u897f\u85cf"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "text": "Proportion of Confirmed Cases in SouthWest"
#         }
#     ]
# };
# myChart_af277015047c4434836e572254ce9bb9.setOption(option_af277015047c4434836e572254ce9bb9);
#
#     });
# </script>
