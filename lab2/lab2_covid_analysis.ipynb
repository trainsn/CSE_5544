# %%
import pandas as pd

# %%
# preprocessing data
dxy_area = pd.read_csv('DXYArea.csv')
dxy_area = dxy_area[ (dxy_area.countryName == '中国') & (dxy_area.provinceName != '中国')]
dxy_area['updateTime'] = pd.to_datetime(dxy_area.updateTime).dt.date
dxy_area = dxy_area.drop_duplicates(['provinceName','updateTime']).reset_index(drop=True)
dxy_area = dxy_area[['provinceName','province_confirmedCount','province_curedCount','province_deadCount','updateTime']]

# %%
current = dxy_area.drop_duplicates(['provinceName']).reset_index(drop=True)
current['provinceName'][0] = '香港'
current['provinceName'][1] = '新疆'
current['provinceName'][2] = '北京'
current['provinceName'][3] = '四川'
current['provinceName'][4] = '甘肃'
current['provinceName'][5] = '上海'
current['provinceName'][6] = '广东'
current['provinceName'][7] = '台湾'
current['provinceName'][8] = '河北'
current['provinceName'][9] = '陕西'
current['provinceName'][10] = '山西'
current['provinceName'][11] = '云南'
current['provinceName'][12] = '重庆'
current['provinceName'][13] = '内蒙古'
current['provinceName'][14] = '山东'
current['provinceName'][15] = '浙江'
current['provinceName'][16] = '天津'
current['provinceName'][17] = '辽宁'
current['provinceName'][18] = '福建'
current['provinceName'][19] = '江苏'
current['provinceName'][20] = '海南'
current['provinceName'][21] = '澳门'
current['provinceName'][22] = '吉林'
current['provinceName'][23] = '湖北'
current['provinceName'][24] = '江西'
current['provinceName'][25] = '黑龙江'
current['provinceName'][26] = '安徽'
current['provinceName'][27] = '贵州'
current['provinceName'][28] = '湖南'
current['provinceName'][29] = '河南'
current['provinceName'][30] = '广西'
current['provinceName'][31] = '宁夏'
current['provinceName'][32] = '青海'
current['provinceName'][33] = '西藏'
current
# Out:
# c:\venv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\venv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\venv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# c:\venv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# c:\venv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\venv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# c:\venv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\venv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# c:\venv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# c:\venv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# c:\venv\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# c:\venv\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# c:\venv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# c:\venv\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# c:\venv\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# c:\venv\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\venv\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    provinceName  province_confirmedCount  province_curedCount  \
# 0            香港                     1655                 1254
# 1            新疆                       77                   73
# 2            北京                      929                  752
# 3            四川                      599                  590
# 4            甘肃                      167                  165
# 5            上海                      732                  691
# 6            广东                     1650                 1636
# 7            台湾                      451                  440
# 8            河北                      349                  340
# 9            陕西                      321                  315
# 10           山西                      201                  198
# 11           云南                      188                  183
# 12           重庆                      583                  576
# 13          内蒙古                      249                  237
# 14           山东                      793                  785
# 15           浙江                     1270                 1267
# 16           天津                      203                  195
# 17           辽宁                      164                  150
# 18           福建                      363                  361
# 19           江苏                      654                  654
# 20           海南                      171                  165
# 21           澳门                       46                   45
# 22           吉林                      155                  153
# 23           湖北                    68135                63623
# 24           江西                      932                  931
# 25          黑龙江                      947                  934
# 26           安徽                      991                  985
# 27           贵州                      147                  145
# 28           湖南                     1019                 1015
# 29           河南                     1276                 1254
# 30           广西                      254                  252
# 31           宁夏                       75                   75
# 32           青海                       18                   18
# 33           西藏                        1                    1
#
#     province_deadCount  updateTime
# 0                   10  2020-07-16
# 1                    3  2020-07-16
# 2                    9  2020-07-16
# 3                    3  2020-07-16
# 4                    2  2020-07-16
# 5                    7  2020-07-16
# 6                    8  2020-07-15
# 7                    7  2020-07-15
# 8                    6  2020-07-15
# 9                    3  2020-07-15
# 10                   0  2020-07-15
# 11                   2  2020-07-15
# 12                   6  2020-07-15
# 13                   1  2020-07-13
# 14                   7  2020-07-13
# 15                   1  2020-07-12
# 16                   3  2020-07-12
# 17                   2  2020-07-11
# 18                   1  2020-07-11
# 19                   0  2020-06-30
# 20                   6  2020-06-26
# 21                   0  2020-06-26
# 22                   2  2020-06-07
# 23                4512  2020-06-05
# 24                   1  2020-06-03
# 25                  13  2020-06-03
# 26                   6  2020-04-24
# 27                   2  2020-04-19
# 28                   4  2020-04-18
# 29                  22  2020-04-14
# 30                   2  2020-04-02
# 31                   0  2020-03-16
# 32                   0  2020-02-23
# 33                   0  2020-02-23

# %%
from pyecharts import Map

province = current['provinceName'].values.tolist()
confirmedCount = current['province_confirmedCount'].values.tolist()
print(len(province), len(confirmedCount))

map = Map("Cumulative Confirmed Cases", '', width=1200, height=600)

range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
map.add("Confirmed Cases", province, confirmedCount, visual_range=[0, 2000], maptype='china', is_visualmap=True, visual_range_color=range_color, visual_text_color='#000', is_map_symbol_show=False, is_label_show=True)
# Out:
# 34 34
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="05ab4bfba6e4469499fc262aa628e5de" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_05ab4bfba6e4469499fc262aa628e5de = echarts.init(document.getElementById('05ab4bfba6e4469499fc262aa628e5de'), 'light', {renderer: 'canvas'});
#
# var option_05ab4bfba6e4469499fc262aa628e5de = {
#     "animation": true,
#     "series_id": 8060237,
#     "visualMap": {
#         "calculable": true,
#         "splitNumber": 5,
#         "showLabel": true,
#         "left": "left",
#         "max": 2000,
#         "min": 0,
#         "type": "continuous",
#         "inRange": {
#             "color": [
#                 "#313695",
#                 "#4575b4",
#                 "#74add1",
#                 "#abd9e9",
#                 "#e0f3f8",
#                 "#ffffbf",
#                 "#fee090",
#                 "#fdae61",
#                 "#f46d43",
#                 "#d73027",
#                 "#a50026"
#             ]
#         },
#         "orient": "vertical",
#         "textStyle": {
#             "color": "#000"
#         },
#         "text": [
#             "high",
#             "low"
#         ],
#         "top": "bottom"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "mapType": "china",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "name": "Confirmed Cases",
#             "showLegendSymbol": false,
#             "data": [
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1655
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 929
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 599
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 167
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 732
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1650
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 451
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 349
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 321
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 201
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 188
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 583
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 249
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 793
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1270
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 203
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 164
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 363
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 654
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 171
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 68135
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 932
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 947
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 991
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1019
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1276
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 254
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "type": "map",
#             "roam": true,
#             "symbol": "circle"
#         }
#     ],
#     "legend": [
#         {
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "Confirmed Cases"
#             ],
#             "show": true,
#             "left": "center",
#             "top": "top"
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto",
#             "text": "Cumulative Confirmed Cases",
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "toolbox": {
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "left": "95%",
#         "orient": "vertical"
#     }
# };
# myChart_05ab4bfba6e4469499fc262aa628e5de.setOption(option_05ab4bfba6e4469499fc262aa628e5de);
#
#     });
# </script>

# %%
# attr, value要显示的数值
value = [20, 100]
attr = ['余杭区', '萧山区']

# 图框的基本特性
m = Map('杭州地图示例图', width=600, height=400)

# 添加数据到图框中
m.add('', attr, value, maptype=u'杭州', visual_range=[0, 100], is_visualmap=True, visual_text_color='#000')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'hang2_zhou1': '/nbextensions/echarts-china-cities-js/zhe4_jiang1_hang2_zhou1'
#         }
#     });
# </script>
#     <div id="0bebd5f6a964457eabf8cfa237bdd728" style="width:600px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'hang2_zhou1'], function(echarts) {
#
# var myChart_0bebd5f6a964457eabf8cfa237bdd728 = echarts.init(document.getElementById('0bebd5f6a964457eabf8cfa237bdd728'), 'light', {renderer: 'canvas'});
#
# var option_0bebd5f6a964457eabf8cfa237bdd728 = {
#     "animation": true,
#     "series_id": 425949,
#     "visualMap": {
#         "calculable": true,
#         "splitNumber": 5,
#         "showLabel": true,
#         "left": "left",
#         "max": 100,
#         "min": 0,
#         "type": "continuous",
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "orient": "vertical",
#         "textStyle": {
#             "color": "#000"
#         },
#         "text": [
#             "high",
#             "low"
#         ],
#         "top": "bottom"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "mapType": "\u676d\u5dde",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "showLegendSymbol": true,
#             "data": [
#                 {
#                     "name": "\u4f59\u676d\u533a",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u8427\u5c71\u533a",
#                     "value": 100
#                 }
#             ],
#             "type": "map",
#             "roam": true,
#             "symbol": "circle"
#         }
#     ],
#     "legend": [
#         {
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 ""
#             ],
#             "show": true,
#             "left": "center",
#             "top": "top"
#         }
#     ],
#     "title": [
#         {
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto",
#             "text": "\u676d\u5dde\u5730\u56fe\u793a\u4f8b\u56fe",
#             "left": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             }
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "toolbox": {
#         "show": true,
#         "feature": {
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             }
#         },
#         "top": "center",
#         "left": "95%",
#         "orient": "vertical"
#     }
# };
# myChart_0bebd5f6a964457eabf8cfa237bdd728.setOption(option_0bebd5f6a964457eabf8cfa237bdd728);
#
#     });
# </script>
